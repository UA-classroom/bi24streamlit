# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel("supermarkt_sales.xlsx")

# %%
df
# Out:
#      Unnamed: 0   Invoice ID Branch       City Customer_type  Gender  \
# 0           NaN  750-67-8428      A     Yangon        Member  Female
# 1           NaN  226-31-3081      C  Naypyitaw        Normal  Female
# 2           NaN  631-41-3108      A     Yangon        Normal    Male
# 3           NaN  123-19-1176      A     Yangon        Member    Male
# 4           NaN  373-73-7910      A     Yangon        Normal    Male
# ..          ...          ...    ...        ...           ...     ...
# 995         NaN  233-67-5758      C  Naypyitaw        Normal    Male
# 996         NaN  303-96-2227      B   Mandalay        Normal  Female
# 997         NaN  727-02-1313      A     Yangon        Member    Male
# 998         NaN  347-56-2442      A     Yangon        Normal    Male
# 999         NaN  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Invoice ID', 'Branch', 'City', 'Customer_type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
df
# Out:
#       Invoice ID Branch       City Customer_type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df.to_csv("modified_supermarket_sales.csv")

# %%
def load_data():
    df = pd.read_csv("re_modified_supermarket_sales.csv")
    df["hour"] = pd.to_datetime(df["Time"]).dt.hour
    df["month"] = pd.to_datetime(df["Date"]).dt.month
    df["year"] = pd.to_datetime(df["Date"]).dt.year
    df['Day of Week'] = pd.to_datetime(df['Date']).dt.day_name()
    df['Profit'] = df['Total'] - df['cogs']
    return df

df = load_data()
# Out:
# C:\Users\Jobb\AppData\Local\Temp\ipykernel_20224\3112161186.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["hour"] = pd.to_datetime(df["Time"]).dt.hour

# %%
df["year"].unique()
# Out:
# array([2021, 2022])

# %%
df["Total"].sum()
# Out:
# 322966.749

# %%
df
# Out:
#      Unnamed: 0.1  Unnamed: 0   Invoice ID Branch       City Customer_type  \
# 0               0         NaN  750-67-8428      A     Yangon        Member
# 1               1         NaN  226-31-3081      C  Naypyitaw        Normal
# 2               2         NaN  631-41-3108      A     Yangon        Normal
# 3               3         NaN  123-19-1176      A     Yangon        Member
# 4               4         NaN  373-73-7910      A     Yangon        Normal
# ..            ...         ...          ...    ...        ...           ...
# 995           995         NaN  233-67-5758      C  Naypyitaw        Normal
# 996           996         NaN  303-96-2227      B   Mandalay        Normal
# 997           997         NaN  727-02-1313      A     Yangon        Member
# 998           998         NaN  347-56-2442      A     Yangon        Normal
# 999           999         NaN  849-09-3807      A     Yangon        Member
#
# ...

# %%
df["City"].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df["Customer_type"].unique()
# Out:
# array(['Member', 'Normal'], dtype=object)

# %%
df['Customer_type'].value_counts()
# Out:
# Customer_type
# Member    501
# Normal    499
# Name: count, dtype: int64

# %%
df['Customer_type'].value_counts().reset_index()
# Out:
#   Customer_type  count
# 0        Member    501
# 1        Normal    499

# %%
df.groupby("Product line").sum(
    numeric_only=True)[["Total"]].sort_values("Total")
# Out:
#                              Total
# Product line
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Fashion accessories     54305.8950
# Electronic accessories  54337.5315
# Sports and travel       55122.8265
# Food and beverages      56144.8440

# %%
df.groupby("Product line").sum(numeric_only=True)
# Out:
#                         Unnamed: 0.1  Unnamed: 0  Unit price  Quantity  \
# Product line
# Electronic accessories         87509         0.0     9103.77       971
# Fashion accessories            90311         0.0    10173.35       902
# Food and beverages             88022         0.0     9745.54       952
# Health and beauty              75169         0.0     8337.88       854
# Home and lifestyle             79374         0.0     8850.71       911
# Sports and travel              79115         0.0     9460.88       920
#
#                            Tax 5%       Total      cogs  \
# Product line
# Electronic accessories  2587.5015  54337.5315  51750.03
# Fashion accessories     2585.9950  54305.8950  51719.90
# Food and beverages      2673.5640  56144.8440  53471.28
# Health and beauty       2342.5590  49193.7390  46851.18
# Home and lifestyle      2564.8530  53861.9130  51297.06
# Sports and travel       2624.8965  55122.8265  52497.93
#
# ...

# %%
df.groupby("Product line").sum(numeric_only=True)[["Total"]]
# Out:
#                              Total
# Product line
# Electronic accessories  54337.5315
# Fashion accessories     54305.8950
# Food and beverages      56144.8440
# Health and beauty       49193.7390
# Home and lifestyle      53861.9130
# Sports and travel       55122.8265

# %%
df.groupby("hour").sum(numeric_only=True)[["Total"]]
# Out:
#            Total
# hour
# 10    31421.4810
# 11    30377.3295
# 12    26065.8825
# 13    34723.2270
# 14    30828.3990
# 15    31179.5085
# 16    25226.3235
# 17    24445.2180
# 18    26030.3400
# 19    39699.5130
# 20    22969.5270

# %%
s3 = df.groupby("month").sum(numeric_only=True)[
    ["Total"]].sort_values("Total")
s3
# Out:
#             Total
# month
# 7       8714.5275
# 12     12452.6640
# 9      12494.3385
# 10     14986.7655
# 6      15722.0910
# 11     15844.4790
# 4      16386.0270
# 8      16425.5910
# 5      17153.3985
# 2      55337.2995
# 3      67936.7430
# 1      69512.8245

# %%
df.groupby('Date')['Total'].sum().cumsum().reset_index()
# Out:
#            Date        Total
# 0    2021-01-01    1294.6080
# 1    2021-01-02    2483.2920
# 2    2021-01-03    3391.0905
# 3    2021-01-04    3466.8690
# 4    2021-01-05    5639.7600
# ..          ...          ...
# 349  2022-12-26  319826.7765
# 350  2022-12-27  321272.0490
# 351  2022-12-28  322041.1530
# 352  2022-12-30  322892.6610
# 353  2022-12-31  322966.7490
#
# [354 rows x 2 columns]

# %%
df.groupby('Date')['Total'].sum().reset_index()
# Out:
#            Date      Total
# 0    2021-01-01  1294.6080
# 1    2021-01-02  1188.6840
# 2    2021-01-03   907.7985
# 3    2021-01-04    75.7785
# 4    2021-01-05  2172.8910
# ..          ...        ...
# 349  2022-12-26   150.4230
# 350  2022-12-27  1445.2725
# 351  2022-12-28   769.1040
# 352  2022-12-30   851.5080
# 353  2022-12-31    74.0880
#
# [354 rows x 2 columns]

# %%
df.pivot_table(index='Day of Week', 
                              columns='hour', 
                              values='Total', 
                              aggfunc='sum')
# Out:
# hour                10         11         12         13         14         15  \
# Day of Week
# Friday       5329.0860  2509.5525  2622.6060  4556.5170  5462.2890  5853.2040
# Monday       4742.5875  3852.0090  3831.1245  5598.3060  4072.0470  2640.1620
# Saturday     4573.0020  4439.3265  2530.8780  5465.7960  5066.7330  5410.2090
# Sunday       4962.6150  3923.4300  3296.9160  3522.2565  3708.9675  2452.0440
# Thursday     4886.3850  3465.0840  5971.2450  2581.1100  5493.2535  3287.7810
# Tuesday      3295.4985  8070.1950  3510.9270  7266.7875  4411.1655  6214.2885
# Wednesday    3632.3070  4117.7325  4302.1860  5732.4540  2613.9435  5321.8200
#
# hour                16         17         18         19         20
# Day of Week
# Friday       2876.8005  3092.4075  3737.6220  9964.5945  2591.2635
# Monday       3383.4675  4579.2285  4991.0805  5696.7540  3087.3255
# Saturday     2328.1230  3408.6885  2285.8815  5135.4870  3319.2495
# ...
